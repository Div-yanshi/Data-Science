# %%
import numpy as np

# %%
arr=np.array([1,2,3],dtype=np.float32)

# %%
print(arr)
# Out:
# [1. 2. 3.]

# %%
print(arr.nbytes)
# Out:
# 12

# %%
int_arr=arr.astype(np.int64)
print(int_arr.nbytes)
# Out:
# 24
